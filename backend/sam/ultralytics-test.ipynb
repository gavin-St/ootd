# %%
from ultralytics import SAM
from ultralytics import FastSAM
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('IMG_6647.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis('on')
plt.show()

# %%
# Define an inference source
source = "IMG_6646.jpg"

# Create a FastSAM model
model = SAM("mobile_sam.pt")  # or FastSAM-x.pt

# Run inference on an image
# everything_results = model(source, device="cpu", retina_masks=True, imgsz=1024, conf=0.4, iou=0.9)

# Run inference with bboxes prompt
#results = model(source, bboxes=[439, 437, 524, 709])

# Run inference with points prompt
results = model(source, points=[[1500, 2500]], labels=[1])
print(results)

# Run inference with texts prompt
#results = model(source, texts="a photo of a dog")

# Run inference with bboxes and points and texts prompt at the same time
#results = model(source, bboxes=[439, 437, 524, 709], points=[[200, 200]], labels=[1], texts="a photo of a dog")
# Out:
# image 1/1 C:\Users\joshu\Desktop\ootd\backend\sam\IMG_6646.jpg: 1024x1024 1229.5ms
# Speed: 28.2ms preprocess, 1229.5ms inference, 26.2ms postprocess per image at shape (1, 3, 1024, 1024)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: ultralytics.engine.results.Masks object
# names: {0: '0'}
# obb: None
# orig_img: array([[[165, 191, 207],
#         [163, 189, 205],
#         [156, 182, 198],
#         ...,
#         [189, 208, 216],
#         [188, 207, 215],
#         [187, 206, 214]],
#
#        [[171, 197, 213],
#         [173, 199, 215],
#         [157, 183, 199],
#         ...,
#         [185, 204, 212],
#         [184, 203, 211],
#         [183, 202, 210]],
#
#        [[169, 195, 211],
#         [174, 200, 216],
#         [151, 177, 193],
#         ...,
#         [182, 201, 209],
#         [181, 200, 208],
#         [181, 200, 208]],
#
#        ...,
#
#        [[ 55,  59,  60],
#         [ 57,  61,  62],
# ...

# %%
print(results[0].masks.data.shape)
plt.imshow(results[0].masks.data.numpy()[0, :, :])
mask = results[0].masks.data.squeeze()
# Out:
# torch.Size([1, 4032, 3024])

# %%
image_cpy = image.copy()
image_cpy[mask < 0.5] = [255, 255, 255]
plt.imshow(mask, cmap="grey")

# %%
# show_mask(mask, plt.gca())
# show_points(input_point, input_label, plt.gca())
# plt.title(f"Mask {i+1}, Score: {score:.3f}", fontsize=18)
# plt.axis('off')
image_cpy = image.copy()
image_cpy[mask < 0.5] = [255, 255, 255]
plt.imshow(image_cpy)
# plt.show()
# cv2.imwrite("image"+str(i)+".png", cv2.cvtColor(image_cpy, cv2.COLOR_BGR2RGB))

# %%
# show_mask(mask, plt.gca())
# show_points(input_point, input_label, plt.gca())
# plt.title(f"Mask {i+1}, Score: {score:.3f}", fontsize=18)
# plt.axis('off')
image_cpy = image.copy()
image_cpy[mask < 0.5] = [255, 255, 255]
plt.imshow(image_cpy)
# plt.show()
# cv2.imwrite("image"+str(i)+".png", cv2.cvtColor(image_cpy, cv2.COLOR_BGR2RGB))

# %%
# show_mask(mask, plt.gca())
# show_points(input_point, input_label, plt.gca())
# plt.title(f"Mask {i+1}, Score: {score:.3f}", fontsize=18)
# plt.axis('off')
image_cpy = image.copy()
image_cpy[mask < 0.5] = [255, 255, 255]
plt.imshow(image_cpy)
# plt.show()
# cv2.imwrite("image"+str(i)+".png", cv2.cvtColor(image_cpy, cv2.COLOR_BGR2RGB))
